# %%
import pandas as pd
import numpy as np

# %%
df_path = r'C:\animation_technique_classification\Data\Raw_Data\Raw_Data.csv'

df = pd.read_csv(df_path)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2370 entries, 0 to 2369
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 2370 non-null   int64
#  1   Title                2370 non-null   str
#  2   Country              2369 non-null   str
#  3   Director             2324 non-null   str
#  4   Studio               2236 non-null   str
#  5   Animation technique  2352 non-null   str
#  6   Type                 192 non-null    str
#  7   Notes                1725 non-null   str
#  8   Release date         2354 non-null   str
#  9   Duration             2319 non-null   str
# dtypes: int64(1), str(9)
# memory usage: 185.3 KB

# %%
df.sample(15)
# Out:
#       Year                                              Title  \
# 2086  2024                                 Boys Go to Jupiter
# 1654  2021   Detective Conan: The Scarlet Bullet 名探偵コナン 緋色の弾丸
# 1362  2019  Captain Sabertooth and the Magic Diamond Kapte...
# 2123  2024                 Gracie & Pedro: Pets To The Rescue
# 1088  2017     GadgetGang in Outer Space BugiGangue no Espaço
# 1235  2018                          Funan [ citation needed ]
# 1264  2018                        La Leyenda del Charro Negro
# 1459  2019                    Teen Titans Go! vs. Teen Titans
# 1215  2018  Coconut the Little Dragon: Into the Jungle Der...
# 1099  2017                      Hey Arnold!: The Jungle Movie
# 2213  2024  Wonderful Pretty Cure! The Movie: A Grand Adve...
# 167   2011  The Jungle Bunch: Back to the Ice Floe Les As ...
# 1743  2021                   Sing a Bit of Harmony アイの歌声を聴かせて
# 1003  2016                Sinbad: Pirates of the Seven Storms
# ...

# %%
df['Release date'] = pd.to_datetime(df['Release date'], errors='coerce')

# %%
df = df.dropna(subset='Release date')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1417 entries, 0 to 2367
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 1417 non-null   int64
#  1   Title                1417 non-null   str
#  2   Country              1417 non-null   str
#  3   Director             1383 non-null   str
#  4   Studio               1308 non-null   str
#  5   Animation technique  1402 non-null   str
#  6   Type                 107 non-null    str
#  7   Notes                995 non-null    str
#  8   Release date         1417 non-null   datetime64[us]
#  9   Duration             1386 non-null   str
# dtypes: datetime64[us](1), int64(1), str(8)
# memory usage: 121.8 KB

# %%
df['Release date']
# Out:
# 0      2010-01-22
# 2      2010-03-05
# 3      2010-10-07
# 4      2014-07-10
# 6      2010-11-26
#           ...
# 2362   2025-02-11
# 2363   2025-09-23
# 2364   2025-09-12
# 2366   2025-01-02
# 2367   2025-10-24
# Name: Release date, Length: 1417, dtype: datetime64[us]

# %%
df = df.drop(['Type', 'Notes'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1417 entries, 0 to 2367
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 1417 non-null   int64
#  1   Title                1417 non-null   str
#  2   Country              1417 non-null   str
#  3   Director             1383 non-null   str
#  4   Studio               1308 non-null   str
#  5   Animation technique  1402 non-null   str
#  6   Release date         1417 non-null   datetime64[us]
#  7   Duration             1386 non-null   str
# dtypes: datetime64[us](1), int64(1), str(6)
# memory usage: 99.6 KB

# %% [markdown]
# ## Feature adding

# %%
df['Release Year'] = df['Release date'].dt.year
df['Release month'] = df['Release date'].dt.month
df['Release day'] = df['Release date'].dt.day

# %%
df['is_holiday'] = df['Release date'].dt.month.isin([11, 12])

# %%
df['Duration_Minutes'] = df['Duration'].str.extract('(\d+)').astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\jyusu\AppData\Local\Temp\ipykernel_21396\1532389331.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['Duration_Minutes'] = df['Duration'].str.extract('(\d+)').astype(float)

# %%
df
# Out:
#       Year                                              Title  \
# 0     2010  AAA - The Movie AAA, la película: Sin límite e...
# 2     2010                    Alice in Wonderland (2010 film)
# 3     2010                 Animals United Konferenz der Tiere
# 4     2010  Anpanman: Blacknose and the Magical Song ja:それ...
# 6     2010                       Las aventuras de Don Quijote
# ...    ...                                                ...
# 2362  2025                    The Witcher: Sirens of the Deep
# 2363  2025                                               Yooz
# 2364  2025  You and Idol Pretty Cure the Movie: For You! O...
# 2366  2025                     Zanna: Whisper of Volcano Isle
# 2367  2025               Zombie Land Saga: Yumeginga Paradise
#
#                                Country  \
# 0                               Mexico
# 2                        United States
# 3                              Germany
# 4                                Japan
# ...

# %%
df['movie_category'] = pd.cut(df['Duration_Minutes'],
                               bins=[0, 45, 90, 150, 200],
                              labels=['short', 'standart', 'long', 'epic'])

# %%
df.sample(5)
# Out:
#       Year                              Title        Country  \
# 177   2011             Leapfrog: Phonics Farm  United States
# 1688  2021      Justice Society: World War II  United States
# 1581  2020  Revue Starlight Rondo Rondo Rondo          Japan
# 2336  2025         The Quest Csongor és Tünde        Hungary
# 676   2014                  Tale of the Rally          China
#
#                     Director                                         Studio  \
# 177               Ron Myrick  Chris D'Angelo Productions LeapFrog Lionsgate
# 1688           Jeff Wamester        Warner Bros. Animation DC Entertainment
# 1581       Tomohiro Furukawa                                  Kinema Citrus
# 2336  Csaba Máli Zsolt Pálfi                          Cinemon Entertainment
# 676           Zheng Chongxin                                            NaN
#
#      Animation technique Release date     Duration  Release Year  \
# 177          Traditional   2011-11-08   38 minutes          2011
# ...

# %%
df = df.drop(columns=['Year', 'Release date', 'Duration'])

# %%
df.sample(5)
# Out:
#                                         Title        Country  \
# 1155                        Si Juki the Movie      Indonesia
# 1736      Scooby-Doo! The Sword and the Scoob  United States
# 1568                       Oresuki: Game Over          Japan
# 1265   Liz and the Blue Bird Rizu to Aoi tori          Japan
# 1797  Detective Conan: The Bride of Halloween          Japan
#
#                                      Director                  Studio  \
# 1155                               Faza Meonk         Falcon Pictures
# 1736  Maxwell Atoms Mel Zwyer Christina Sotta  Warner Bros. Animation
# 1568                          Noriaki Akitaya                 Connect
# 1265                             Naoko Yamada         Kyoto Animation
# 1797                         Susumu Mitsunaka       TMS Entertainment
#
#      Animation technique  Release Year  Release month  Release day  \
# 1155         Traditional          2017             12           28
# ...
